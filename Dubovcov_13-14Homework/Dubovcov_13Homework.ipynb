# %%
#комбинаторика

# %%
#1

a = 30 * 29 *28
print(f"Задача 1: {a}")
# Out:
# Задача 1: 24360

# %%
# 2
#для каждого письма 2 вариантна

a = 2**10
print(f"Задача 2: {a}")
# Out:
# Задача 1: 1024

# %%
# 3

a = 50+30
print(f"Задача 3: {a}")
# Out:
# Задача 3: 80

# %%
# 5
from math import factorial

a = factorial(7)
print(f"Задача 5: {a}")
# Out:
# Задача 5: 5040

# %%
# 6
from math import perm

a = 10*9*8*7*6
b = perm(10, 5)

print(f"Задача 6: {a}")
print(f"Задача 6: {b}")
# Out:
# Задача 6: 30240
# Задача 6: 30240

# %%
# 7
# 15 + 14 + 13 + ... + 1 
from math import comb

a = comb(16, 2)
print(f"Задача 7: {a}")
# Out:
# Задача 7: 120

# %%
# 8
from math import comb
a = comb(10, 5)

print(f"Задача 8: {a}")
# Out:
# Задача 8: 252

# %%
#9 ???

# %%
# 10 ???

# %%
# 11
a = comb(25, 6) * comb(19, 9) * comb(10, 10)

print(f"Задача 11: {a}")
# Out:
# Задача 11: 16360143800

# %%
# 12

a = factorial(7) / (factorial(3) * factorial(2) * factorial(2))
print(f"Задача 12: {a}")
# Out:
# Задача 12: 210.0

# %%
#--------------

#1 
a= (5/9) * (4/8) * (3/7) * 100
b =   comb(5, 3) / comb(9, 3) * 100 

print(f"Задача 1: {a}")
print(f"Задача 1: {b}")
# Out:
# Задача 1: 11.904761904761903
# Задача 1: 11.904761904761903

# %%
#2

a = 10 ** 3 # все варианты
b = 10 * 9 * 8 # все различны

c = b / a
print(f"Задача 2: {100 - c*100}")
# Out:
# Задача 2: 28.0

# %%
# 3

# %%
#4 

a = 5**6 #все случаи
b = 5 *  # все не пустые
print(f"Задача 4: {a*100}")
# Out:
# Задача 4: 2.1736711087157383

# %%
#--------------

#1

a = 10/15 * 9/14 + 5/15 * 4/14

print(f"Задача 1: {a}")
# Out:
# Задача 1: 0.5238095238095237

# %%
# 2
# А - 28 Н - 30 ф - 42 АН - 8  АФ - 10 НФ - 5 все - 3
a = 28 + 30 - 8
b = 28 + 30 + 42 -8 - 5 -10 + 3
c = 100 - 28 - 30 - 42 + 5 + 10 + 8 - 3

print(f"Задача 2 а: {a}")
print(f"Задача 2 б: {b}")
print(f"Задача 2 с: {c}")
# Out:
# Задача 2 а: 50
# Задача 2 б: 80
# Задача 2 с: 20

# %%
# 3

1/2
