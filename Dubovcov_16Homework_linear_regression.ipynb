# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('A:/1 - DS phyton/учебные датасеты/kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
your_columns = ['price']

for column in your_columns:
    plt.figure()  # это создает новое окно
    sns.histplot(data=df, x=column)
    plt.title(f'Распределение')
    
plt.show()

# %%
df = df[df['price'] <= 1500000]

# %%
df_model =  df.drop(["id", "date"], axis=1)

# %%
df_model
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
heatdf  = df_model

plt.figure(figsize=(16,10), dpi= 80)
sns.heatmap(heatdf.corr(), xticklabels=heatdf.corr().columns, yticklabels=heatdf.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.title('price', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
df_model.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.109700e+04  21097.000000  21097.000000  21097.000000  2.109700e+04
# mean   5.012777e+05      3.350097      2.080391   2022.189174  1.474278e+04
# std    2.482295e+05      0.920632      0.732479    824.830866  3.994771e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.199500e+05      3.000000      1.500000   1410.000000  5.001000e+03
# 50%    4.450000e+05      3.000000      2.250000   1890.000000  7.552000e+03
# 75%    6.250000e+05      4.000000      2.500000   2500.000000  1.045400e+04
# max    1.500000e+06     33.000000      7.500000   7480.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21097.000000  21097.000000  21097.000000  21097.000000  21097.000000
# mean       1.485306      0.003982      0.200076      3.406977      7.591933
# ...

# %%
df_model =  df_model.drop([ "zipcode", "lat", "long", "yr_renovated", "sqft_above", "sqft_basement" ], axis=1)

# %%
heatdf  = df_model

plt.figure(figsize=(16,10), dpi= 80)
sns.heatmap(heatdf.corr(), xticklabels=heatdf.corr().columns, yticklabels=heatdf.corr().columns, cmap='RdYlGn', center=0, annot=True)

plt.title('price', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
print(df_model.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21097 entries, 0 to 21612
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21097 non-null  float64
#  1   bedrooms       21097 non-null  int64
#  2   bathrooms      21097 non-null  float64
#  3   sqft_living    21097 non-null  int64
#  4   sqft_lot       21097 non-null  int64
#  5   floors         21097 non-null  float64
#  6   waterfront     21097 non-null  int64
#  7   view           21097 non-null  int64
#  8   condition      21097 non-null  int64
#  9   grade          21097 non-null  int64
#  10  yr_built       21097 non-null  int64
#  11  sqft_living15  21097 non-null  int64
#  12  sqft_lot15     21097 non-null  int64
# dtypes: float64(3), int64(10)
# memory usage: 2.3 MB
# None

# %%
plt.figure(figsize=(10, 6))
plt.hist(df_model['price'], bins=30, edgecolor='black')
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='bedrooms', y='price', data=df_model)
plt.title('House Prices by Number of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='view', y='price', data=df_model)
plt.title('House Prices by floors')
plt.xlabel('view')
plt.ylabel('Price')
plt.show()

# %%
df_model.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.109700e+04  21097.000000  21097.000000  21097.000000  2.109700e+04
# mean   5.012777e+05      3.350097      2.080391   2022.189174  1.474278e+04
# std    2.482295e+05      0.920632      0.732479    824.830866  3.994771e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.199500e+05      3.000000      1.500000   1410.000000  5.001000e+03
# 50%    4.450000e+05      3.000000      2.250000   1890.000000  7.552000e+03
# 75%    6.250000e+05      4.000000      2.500000   2500.000000  1.045400e+04
# max    1.500000e+06     33.000000      7.500000   7480.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21097.000000  21097.000000  21097.000000  21097.000000  21097.000000
# mean       1.485306      0.003982      0.200076      3.406977      7.591933
# ...

# %%
your_columns = ["price", "bedrooms", "bathrooms", "sqft_living", "sqft_lot", "floors",	"waterfront", 
"view", "condition", "grade",  "yr_built",  "sqft_living15", "sqft_lot15"]

for column in your_columns:
    plt.figure()  # это создает новое окно
    sns.histplot(data=df_model, x=column)
    plt.title(f'Распределение')
    
plt.show()

# %%
df_model =  df_model.drop(["sqft_lot15",  "sqft_lot"], axis=1)

# %%
plt.figure(figsize=(12, 6))

# Гистограмма
plt.hist(df_model['floors'], bins=30, color='skyblue', 
         edgecolor='black', alpha=0.7)
# Out:
# (array([1.0586e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.8840e+03, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 7.8940e+03, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 1.3400e+02, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 5.9200e+02,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 7.0000e+00]),
#  array([1.        , 1.08333333, 1.16666667, 1.25      , 1.33333333,
#         1.41666667, 1.5       , 1.58333333, 1.66666667, 1.75      ,
#         1.83333333, 1.91666667, 2.        , 2.08333333, 2.16666667,
#         2.25      , 2.33333333, 2.41666667, 2.5       , 2.58333333,
#         2.66666667, 2.75      , 2.83333333, 2.91666667, 3.        ,
#         3.08333333, 3.16666667, 3.25      , 3.33333333, 3.41666667,
#         3.5       ]),
#  <BarContainer object of 30 artists>)

# %%
# автомат  регрессия

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
y = df_model['price']
x = df_model.drop(columns = ['price'])

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21097, dtype: float64

# %%
x
# Out:
#        bedrooms  bathrooms  sqft_living  floors  waterfront  view  condition  \
# 0             3       1.00         1180     1.0           0     0          3
# 1             3       2.25         2570     2.0           0     0          3
# 2             2       1.00          770     1.0           0     0          3
# 3             4       3.00         1960     1.0           0     0          5
# 4             3       2.00         1680     1.0           0     0          3
# ...         ...        ...          ...     ...         ...   ...        ...
# 21608         3       2.50         1530     3.0           0     0          3
# 21609         4       2.50         2310     2.0           0     0          3
# 21610         2       0.75         1020     2.0           0     0          3
# 21611         3       2.50         1600     2.0           0     0          3
# 21612         2       0.75         1020     2.0           0     0          3
#
#        grade  yr_built  sqft_living15
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
reg = LinearRegression().fit(x, y)

# %%
reg.predict(x_test)
# Out:
# array([369257.20586996, 580846.60201867, 704727.36272304, ...,
#        765284.27138787, 797670.13779103, 524116.40382713])

# %%
y_test
# Out:
# 17745    272450.0
# 1840     720000.0
# 4334     705000.0
# 5107     400000.0
# 3203     528000.0
#            ...
# 9574     396500.0
# 11068    870000.0
# 19080    695000.0
# 4851     988830.0
# 1618     549500.0
# Name: price, Length: 4220, dtype: float64

# %%
print("constant: ",reg.intercept_)
print("coefficient: ",reg.coef_)
# Out:
# constant:  5307937.006830824
# coefficient:  [-1.58931215e+04  3.63171617e+04  7.68127414e+01  4.31006288e+04
#   1.35458279e+05  3.33628171e+04  1.90870443e+04  1.04448519e+05
#  -3.04832677e+03  4.83328064e+01]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
y_pred = reg.predict(x_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 115429.7407047633

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 23664516128.80808

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred) * 100
print(f"R² score: {r2:.2f}%")
# Out:
# R² score: 62.22%

# %%
# ручная регресия
y = df_model['price']
x = df_model['bedrooms']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
# ручная регресия
y = df_model['price']
x = df_model['bedrooms']

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

x1 = x_train.values  # Получаем numpy массив
y1 = y_train.values
n = len(x1)

b1 = (n*np.sum(x1*y1) - np.sum(x1)*np.sum(y1)) / (n*np.sum(x1**2) - np.sum(x1)**2)
b0 = np.mean(y1) - b1*np.mean(x1)

print(f"price = {b0:.0f} + {b1:.0f}*bedrooms")
# Out:
# price = 228016 + 81297*bedrooms

# %%
# проверка
y = df_model['price']
x = df_model[['bedrooms']]

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42)

# %%
reg = LinearRegression().fit(x_train, y_train)

print("constant: ",reg.intercept_)
print("coefficient: ",reg.coef_)
# Out:
# constant:  228016.22613958392
# coefficient:  [81297.33760952]
